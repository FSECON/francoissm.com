# %%
import pandas as pd

# Exemple avec l'API Web de StatCan ou un lien CSV direct
# Remplacez par la méthode exacte ou l'URL de votre tableau
url = "https://www150.statcan.gc.ca/n1/tbl/csv/14100287-fra.zip" 

try:
    # Pandas peut lire directement des fichiers ZIP de StatCan s'ils contiennent un CSV
    df = pd.read_csv(url)
    
    # Optionnel : Filtrer ou nettoyer les données ici pour alléger le fichier
    # df = df[df['GEO'] == 'Québec']
    
    # Sauvegarder le fichier localement dans le dépôt GitHub
    df.to_csv("TAB_1410028703_POP_ACTIVE_MENSUELLE.csv", index=False)
    print("Mise à jour réussie du fichier CSV.")
except Exception as e:
    print(f"Erreur lors de la récupération : {e}")
